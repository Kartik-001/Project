# %% [markdown]
# ## Looking at the dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df
# Out:
#         CRIM    ZM  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296  \
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZM       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df['CHAS'].value_counts()
# Out:
# CHAS
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#              CRIM          ZM       INDUS        CHAS         NOX          RM
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000  \
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601613   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.980000  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000  \
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# %matplotlib inline

# %%
import matplotlib as plt

# %%
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot: title={'center': 'CRIM'}>,
#         <AxesSubplot: title={'center': 'ZM'}>,
#         <AxesSubplot: title={'center': 'INDUS'}>,
#         <AxesSubplot: title={'center': 'CHAS'}>],
#        [<AxesSubplot: title={'center': 'NOX'}>,
#         <AxesSubplot: title={'center': 'RM'}>,
#         <AxesSubplot: title={'center': 'AGE'}>,
#         <AxesSubplot: title={'center': 'DIS'}>],
#        [<AxesSubplot: title={'center': 'RAD'}>,
#         <AxesSubplot: title={'center': 'TAX'}>,
#         <AxesSubplot: title={'center': 'PTRATIO'}>,
#         <AxesSubplot: title={'center': 'B'}>],
#        [<AxesSubplot: title={'center': 'LSTAT'}>,
#         <AxesSubplot: title={'center': 'MEDV'}>, <AxesSubplot: >,
#         <AxesSubplot: >]], dtype=object)

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import StratifiedShuffleSplit

X = df.drop('MEDV', axis=1)
y = df['MEDV']
stratified_splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in stratified_splitter.split(df, df['CHAS']):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
df_train = pd.concat([X_train, y_train], axis=1)
df_train
# Out:
#         CRIM    ZM  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315  \
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 155  3.53501   0.0  19.58     1  0.871  6.152  82.6  1.7455    5  403
# 423  7.05042   0.0  18.10     0  0.614  6.103  85.1  2.0218   24  666
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276
# 455  4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666
# 216  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121    5  276
#
#      PTRATIO       B  LSTAT  MEDV
# 254     16.4  392.89   6.57  21.9
# 348     17.0  390.94   5.99  24.5
# ...

# %%
df_train.describe()
# Out:
#              CRIM          ZM       INDUS        CHAS         NOX          RM
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000  \
# mean     3.602786   10.836634   11.344950    0.069307    0.558064    6.279908
# std      8.099353   22.150636    6.877817    0.254290    0.116875    0.712983
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.878750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.210000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630250
# max     73.530000  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000  \
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %% [markdown]
# ## Looking for correlations (training set)

# %%
correlation_matrix = df_train.corr()
correlation_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.679894
# B          0.361761
# ZM         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393710
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ['MEDV', 'RM', 'LSTAT']
scatter_matrix(df_train[attributes], figsize=(12, 8))
# Out:
# array([[<AxesSubplot: xlabel='MEDV', ylabel='MEDV'>,
#         <AxesSubplot: xlabel='RM', ylabel='MEDV'>,
#         <AxesSubplot: xlabel='LSTAT', ylabel='MEDV'>],
#        [<AxesSubplot: xlabel='MEDV', ylabel='RM'>,
#         <AxesSubplot: xlabel='RM', ylabel='RM'>,
#         <AxesSubplot: xlabel='LSTAT', ylabel='RM'>],
#        [<AxesSubplot: xlabel='MEDV', ylabel='LSTAT'>,
#         <AxesSubplot: xlabel='RM', ylabel='LSTAT'>,
#         <AxesSubplot: xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %%
df_train.plot(kind='scatter', x='RM', y='MEDV', alpha=0.8)
# Out:
# <AxesSubplot: xlabel='RM', ylabel='MEDV'>

# %%
correlation_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.679894
# B          0.361761
# ZM         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393710
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %% [markdown]
# ## Addressing missing values

# %%
# filling nil values with the median
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')
imputer.fit(df_train)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([2.86735e-01, 0.00000e+00, 9.90000e+00, 0.00000e+00, 5.38000e-01,
#        6.21000e+00, 7.82000e+01, 3.12220e+00, 5.00000e+00, 3.37000e+02,
#        1.90000e+01, 3.90955e+02, 1.15700e+01, 2.11500e+01])

# %%
value = imputer.transform(df_train)
df_tr = pd.DataFrame(value, columns=df_train.columns)
df_tr.describe()
# Out:
#              CRIM          ZM       INDUS        CHAS         NOX          RM
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000  \
# mean     3.602786   10.836634   11.344950    0.069307    0.558064    6.279908
# std      8.099353   22.150636    6.877817    0.254290    0.116875    0.712983
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.878750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.210000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630250
# max     73.530000  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000  \
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %%
df.head()
# Out:
#       CRIM    ZM  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3  \
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# ## Scikit-learn design

# %% [markdown]
# Estimators are used for training or fitting models to data.
#
# Transformers are used for transforming or preprocessing data.
#
# Predictors are used for making predictions on new data.

# %% [markdown]
# ## Creating a pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # Step 1: Impute missing values
    ('scaler', StandardScaler()),                  # Step 2: Standardize features, StandardScaler for preprocessing
    ('regressor', LinearRegression())       # LinearRegression as the final estimator
])

pipeline.fit(X_train, y_train)
predictions = pipeline.predict(X_test)

mse = mean_squared_error(y_test, predictions)
print('Mean Squared Error: ', mse)
# Out:
# Mean Squared Error:  17.17127504697172

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler()),
    ('regressor', DecisionTreeRegressor(random_state=42))
])

pipeline.fit(X_train, y_train)

predictions = pipeline.predict(X_test)

mse = mean_squared_error(y_test, predictions)
print('Mean Squared Error: ', mse)
# Out:
# Mean Squared Error:  16.975784313725487

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

df = pd.read_csv('data.csv')

X = df.drop('MEDV', axis=1)
y = df['MEDV']

stratified_splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in stratified_splitter.split(df, df['CHAS']):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

models = [
    ('Linear Regression', LinearRegression()),
    ('Ridge Regression', Ridge()),
    ('Lasso Regression', Lasso()),
    ('Random Forest Regressor', RandomForestRegressor()),
    ('Support Vector Regressor', SVR()),
    ('DecisionTreeRegressor', DecisionTreeRegressor())
]

results = []
for name, model in models:
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('regressor', model)
    ])
    
    mse_scores = -cross_val_score(pipeline, X_train, y_train, scoring='neg_mean_squared_error', cv=5)
    
    results.append((name, mse_scores.mean(), mse_scores.std()))

for name, mean, std in results:
    print(f'{name}: Mean MSE = {mean}, Standard Deviation = {std}')
# Out:
# Linear Regression: Mean MSE = 26.107462636034928, Standard Deviation = 7.898523073074735
# Ridge Regression: Mean MSE = 26.070031389354966, Standard Deviation = 7.947847172080058
# Lasso Regression: Mean MSE = 31.12603811980956, Standard Deviation = 10.312490446273056
# Random Forest Regressor: Mean MSE = 11.269430037777774, Standard Deviation = 2.6891368633038106
# Support Vector Regressor: Mean MSE = 35.35450688410796, Standard Deviation = 15.973640849071666
# DecisionTreeRegressor: Mean MSE = 21.999983024691357, Standard Deviation = 6.359699930385986

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler()),
    ('regressor', RandomForestRegressor(random_state=42))
])

pipeline.fit(X_train, y_train)

predictions = pipeline.predict(X_test)

mse = mean_squared_error(y_test, predictions)
print('Mean Squared Error: ', mse)
# Out:
# Mean Squared Error:  8.850784509803912

# %% [markdown]
# ## saving the model

# %%
from joblib import dump, load
dump(model, 'price_predictor.joblib')
# Out:
# ['price_predictor.joblib']
